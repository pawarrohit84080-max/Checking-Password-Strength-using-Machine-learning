# %% [markdown]
# # Importing Required Libraries

# %%
import warnings
warnings.simplefilter('ignore')

import random
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

# %% [markdown]
# # Importing Data

# %%
data = pd.read_csv(r"Password Strength.csv", on_bad_lines='skip')

# we are using "on_bad_lines" to skip the line where it cannot 
# be parsed or have some other issue that prevents them from being processed as expected.

# %%
data.head(10)
# Out:
#            password  strength
# 0          kzde5577         1
# 1          kino3434         1
# 2         visi7k1yr         1
# 3          megzy123         1
# 4       lamborghin1         1
# 5  AVYq1lDE4MgAZfNt         2
# 6          u6c8vhow         1
# 7          v1118714         1
# 8      universe2908         1
# 9          as326159         1

# %%
data.shape
# Out:
# (669640, 2)

# %%
data.isnull().sum()
# Out:
# password    1
# strength    0
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#        password  strength
# 367579      NaN         0

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# password    0
# strength    0
# dtype: int64

# %%
df["strength"].value_counts()
# Out:
# strength
# 1    496801
# 0     89701
# 2     83137
# Name: count, dtype: int64

# %%
sns.countplot(x = 'strength', data = df)
# Out:
# <Axes: xlabel='strength', ylabel='count'>

# %%
x = df['password']

y = df['strength']

# %%
x
# Out:
# 0             kzde5577
# 1             kino3434
# 2            visi7k1yr
# 3             megzy123
# 4          lamborghin1
#               ...
# 669635      10redtux10
# 669636       infrared1
# 669637    184520socram
# 669638       marken22a
# 669639        fxx4pw4g
# Name: password, Length: 669639, dtype: str

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 669635    1
# 669636    1
# 669637    1
# 669638    1
# 669639    1
# Name: strength, Length: 669639, dtype: int64

# %%
x.isnull().sum()
# Out:
# np.int64(0)

# %%
def character(inputs):
    
    characters = []
    for i in inputs:
        characters.append(i)
        
    return characters

# %%
vec = TfidfVectorizer(tokenizer = character)
x = vec.fit_transform(x)

# %%
vec.vocabulary_
# Out:
# {'k': 66,
#  'z': 81,
#  'd': 59,
#  'e': 60,
#  '5': 39,
#  '7': 41,
#  'i': 64,
#  'n': 69,
#  'o': 70,
#  '3': 37,
#  '4': 38,
#  'v': 77,
#  's': 74,
#  '1': 35,
#  'y': 80,
#  'r': 73,
#  'm': 68,
#  'g': 62,
#  '2': 36,
#  'l': 67,
#  'a': 56,
#  'b': 57,
#  'h': 63,
#  'q': 72,
#  'f': 61,
#  't': 75,
#  'u': 76,
#  '6': 40,
#  'c': 58,
#  '8': 42,
#  'w': 78,
#  '9': 43,
#  '0': 34,
#  'j': 65,
#  'p': 71,
#  '@': 49,
#  '-': 31,
#  'x': 79,
#  '.': 32,
#  '>': 47,
#  '&': 26,
#  '?': 48,
#  '<': 45,
#  '!': 21,
#  ';': 44,
#  '_': 54,
#  '%': 25,
#  '±': 99,
#  '"': 22,
#  '~': 85,
#  '+': 30,
#  '^': 53,
#  '/': 33,
#  '$': 24,
#  ')': 28,
#  ' ': 20,
#  '(': 27,
#  '#': 23,
#  'ú': 138,
#  '*': 29,
#  '`': 55,
#  '{': 82,
#  '}': 84,
#  '[': 50,
#  ']': 52,
#  'þ': 142,
#  'ó': 132,
#  'ô': 133,
#  '=': 46,
#  '\\': 51,
#  '\x1c': 17,
#  '³': 101,
#  '¿': 112,
#  '\x16': 12,
#  'ò': 131,
#  '·': 105,
#  '\x1e': 19,
#  '\x19': 15,
#  '\x05': 3,
#  '\x1b': 16,
#  'å': 120,
#  '‚': 147,
#  'ä': 119,
#  'à': 115,
#  'õ': 134,
#  'ß': 114,
#  '´': 102,
#  '«': 96,
#  'ð': 129,
#  'â': 117,
#  '°': 98,
#  '|': 83,
#  '\x7f': 86,
#  '²': 100,
#  '¾': 111,
#  'ÿ': 143,
#  '\x08': 5,
#  'ê': 125,
#  'á': 116,
#  '\x10': 8,
#  '\x17': 13,
#  'º': 107,
#  '¡': 90,
#  '÷': 136,
#  'í': 126,
#  'µ': 103,
#  'ý': 141,
#  'ü': 140,
#  'û': 139,
#  'ö': 135,
#  '×': 113,
#  '¨': 95,
#  '\xa0': 89,
#  'æ': 121,
#  'è': 123,
#  'ù': 137,
#  'é': 124,
#  '\x06': 4,
#  'ñ': 130,
#  '\x81': 87,
#  '\x11': 9,
#  '—': 146,
#  '›': 151,
#  '‹': 150,
#  'œ': 144,
#  '™': 152,
#  '¦': 93,
#  '\x0f': 7,
#  'ï': 128,
#  'ç': 122,
#  '\x12': 10,
#  '\x8d': 88,
#  'î': 127,
#  '¹': 106,
#  '¶': 104,
#  '¼': 109,
#  '…': 149,
#  '\x13': 11,
#  '\x1d': 18,
#  '\x04': 2,
#  '\x0e': 6,
#  '\x02': 1,
#  '¯': 97,
#  '\x01': 0,
#  '‡': 148,
#  '¤': 92,
#  '¢': 91,
#  'ƒ': 145,
#  '§': 94,
#  'ã': 118,
#  '»': 108,
#  '\x18': 14,
#  '½': 110}

# %%
x.shape
# Out:
# (669639, 153)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1000)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (669639, 153)
# (535711, 153)
# (133928, 153)

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_test = lr.predict(x_test)

y_pred_train = lr.predict(x_train)

# %%
test_acc = accuracy_score(y_test, y_pred_test)

train_acc = accuracy_score(y_train, y_pred_train)

# %%
print(test_acc)

print(train_acc)
# Out:
# 0.8184920255659758
# 0.8192794249138061

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

gb_model = HistGradientBoostingClassifier(
   
    max_depth=3,
    random_state=42
)

# %%
gb_model.fit(x_train.toarray(), y_train)
y_pred_gb = gb_model.predict(x_test.toarray())

# %%
test_acc_1 = accuracy_score(y_test, y_pred_gb)
test_acc_1
# Out:
# 0.9320455767277941

# %% [markdown]
# # Data Validation

# %%
#user_password = ["password@123"]
#user_inp = vec.transform(user_password)

#y_pred = gb_model.predict(user_inp)

#print("Password Strength:", y_pred[0])

user_inp = input()
user_inp = np.array([user_inp])
user_inp = vec.transform(user_inp).toarray()
y_pred = gb_model.predict(user_inp)
print("Password Strength:", y_pred[0])
# Out:
# Password Strength: 1
